# %% [markdown]
# # core
#
# > There are no modules here, yet.

# %%
#| default_exp core

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(): pass

# %%
# Test that foo() can be called without error
foo()

# %%
#| hide
import nbdev; nbdev.nbdev_export()
